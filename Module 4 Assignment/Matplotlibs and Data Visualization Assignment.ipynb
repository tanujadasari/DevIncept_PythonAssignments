# %% [markdown]
# # Data Visualization And Matplotlibs Assignment by Tanuja Dasari

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Data Visualization Using Python Libraries

# %%
b=pd.read_csv("E:/devincept/heart.csv")
b
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
plt.bar(x=b['age'],height=b['thalachh'])
plt.xlabel('age')
plt.ylabel('thalachh')
# Out:
# Text(0, 0.5, 'thalachh')

# %%
plt.figure(figsize=(5,5))

plt.bar(x=b['age'],height=b['chol'])
plt.xlabel('age')
plt.ylabel('chol')
# Out:
# Text(0, 0.5, 'chol')

# %%
x=b.chol
y=b.oldpeak

plt.scatter(x,y)
plt.show()

# %%
d= sns.distplot(b['chol'])

# %%
c= sns.distplot(b['output'])

# %%
x = sns.distplot(b['thalachh'])

# %%
b.boxplot(by ='age', column =['thalachh'], grid = True)

# %%
b.boxplot(by ='thalachh', column =['age'], grid = True)

# %%
b.boxplot(by ='age', column =['output'], grid = False)

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.heatmap(b.corr(), center=0, cmap='BrBG', annot=False)

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.heatmap(b.corr(), center=0, cmap='BrBG', annot=True)

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.heatmap(b.corr(), center=0, cmap='Greens')
ax.set_title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.heatmap(b.corr(), center=0, cmap='Greens')
ax.set_title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,x = plt.subplots()  
x.plot([2,4, 6, 12], [3, 7, 9, 17])

# %%
plt.plot([5,6,7,8],[9,13,15,20])

# %%
plt.figure()

# %%
fid,a=plt.subplots(10,5)

# %% [markdown]
# ##  <span style='color:red'>TYPES OF PLOTS</span>

# %% [markdown]
# ###  <span style='color:green'> LINE PLOT  </span>

# %%
x = np.linspace(10, 5, 1000)

fig, a = plt.subplots()
a.plot(x, x**2, label='quadratic',color='red')
a.plot(x, x, label='linear',color='black')
a.plot(x, x**3, label='cubic',color='blue') 
a.set_xlabel('x label')  
a.set_ylabel('y label')  
a.set_title("Plot")  
a.legend()

# %%
fig,x = plt.subplots()  
x=[2,4, 6, 12]
y=[3, 7, 9, 17]
plt.plot(x,y,color='red')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
fig,
x=[2,6,10,14]
y=[2,6,10,14]
plt.plot(x,y,color='green',label='line1')
x=[2,6,10,14]
y=[1,5,11,16]
plt.plot(x,y,color='orange',label='line2')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
fig,
x=[2,6,10,14]
y=[1,5,11,16]
plt.plot(x,y,color='orange',linestyle='dashdot',linewidth=2,marker='o',markerfacecolor='red',markersize='5')
plt.xlabel('x-axis',color='green') 
plt.ylabel('y-axis',color='brown')
plt.title('Line Plot')
plt.show()

# %% [markdown]
#     ###  <span style='color:red'> Bar PLOT  </span>

# %%
fig,x = plt.subplots()  
x=[2,4, 6, 12]
y=[3, 7, 9, 17]
plt.bar(x,y,color='blue')
plt.title('Bar  Plot')
# Out:
# Text(0.5, 1.0, 'Bar  Plot')

# %%
fig,x = plt.subplots()  
x=[2,4, 6, 12]
y=[3, 7, 9, 17]
plt.bar(x,y,color = ['blue', 'red'])
plt.title('Bar  Plot')
# Out:
# Text(0.5, 1.0, 'Bar  Plot')

# %% [markdown]
# ###  <span style='color:purple'> HISTOGRAM  </span>

# %%
a =  [5,75,62,35,90,25,34,89,47,13,15,90,130,145,47,23,55] 

range = (0, 100) 
bins=10

plt.hist(a,bins,range, color = 'orange',histtype = 'step', ) 

plt.xlabel('x-axis') 

plt.ylabel('y-axis') 

plt.show()

# %% [markdown]
# ###  <span style='color:BROWN'>  SCATTER PLOT  </span>

# %%
x=b.chol
y=b.oldpeak

plt.scatter(x,y,color='red')
plt.title('scatter plot')
plt.show()

# %%
x=b.age
y=b.chol

plt.scatter(x,y,color='red',marker='p')
plt.show()

# %% [markdown]
# ###  <span style='color:gold'>  PIE-CHART  </span>

# %%
assigments=['assign1','assign2','assign3','assign4','assign5']
s = [5, 6, 3, 4,2] 

colors=['r','b','y','g','lightskyblue']
plt.pie(s, labels = assigments, colors=colors, startangle=90, shadow = True, explode = (0.2, 0, 0, 0,0), radius = 1.5, autopct = '%1.1f%%') 
plt.title('Pie-Chart')
plt.legend()
plt.show()

# %% [markdown]
# ###  <span style='color:LIGHTSKYBLUE'>  CURVES OF EQUATIONS  </span>

# %%
x = np.arange(0, 10*(np.pi), 2.5) 
y = np.cos(x) 

plt.plot(x, y) 

plt.show()

# %%
x = np.arange(0, 10*(np.pi),0.55) 
y = np.tan(x) 

plt.plot(x, y,color='orange') 

plt.show()

# %% [markdown]
# ###  <span style='color:ORANGE'> BOX PLOT  </span>

# %%
np.random.seed(10) 
a= np.random.normal(50, 20, 100)
b= np.random.normal(30, 10, 100)
c= np.random.normal(20, 60, 200)
s=[a,b,c]
fg = plt.figure(figsize =(5, 5))
axis = fg.add_axes([0, 0, 1, 1])
axis.boxplot(s)
plt.show()
